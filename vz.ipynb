# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_page(url):
    try:
        page = requests.get(url)
        if page.status_code==200:
            soup= BeautifulSoup(page.text,'lxml')
            return soup
        else:
            print('error aa rhi hai',e)
    except Exception as e:
        print('error',e)

# %%
soups = []
for i in range(33):
    start = i+1
    url = f"https://www.amazon.in/Honor-Blue-4GB-64GB-Storage/product-reviews/B07R2W2WTS/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={start}"   
    soup = get_page(url)
    if soup:
        print("downloaded page")
        soups.append(soup)
    else:
        print("ye kya ho rha hai")
# Out:
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# error ('Connection broken: OSError("(10053, \'WSAECONNABORTED\')")', OSError("(10053, 'WSAECONNABORTED')"))
# ye kya ho rha hai
# error HTTPSConnectionPool(host='www.amazon.in', port=443): Max retries exceeded with url: /Honor-Blue-4GB-64GB-Storage/product-reviews/B07R2W2WTS/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=19 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000217A7DA7EF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ye kya ho rha hai
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# downloaded page
# ...

# %%
import pandas as pd
dataset =pd.DataFrame(reviewlist)
dataset.to_csv("collection_review.csv")

# %%
dataset
# Out:
#                   date                        helpful  \
# 0    20 September 2018  227 people found this helpful
# 1     18 November 2018  136 people found this helpful
# 2      27 October 2018  132 people found this helpful
# 3          10 May 2019   41 people found this helpful
# 4      3 February 2019   33 people found this helpful
# 5          26 May 2019   27 people found this helpful
# 6          27 May 2019   17 people found this helpful
# 7      31 January 2019   22 people found this helpful
# 8          11 May 2019   19 people found this helpful
# 9      7 December 2018   17 people found this helpful
# 10    10 November 2018   16 people found this helpful
# 11      6 October 2018   13 people found this helpful
# 12   25 September 2018   14 people found this helpful
# 13    12 December 2018   13 people found this helpful
# 14     22 October 2018   14 people found this helpful
# 15     16 October 2018   11 people found this helpful
# ...
